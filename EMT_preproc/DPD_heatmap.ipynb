# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# %matplotlib inline  
# %matplotlib notebook
# %pylab
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib
# /usr/lib64/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
DPD_vals = pd.read_excel('EMT_DPDs_singlesheet_3.xlsx',index_col=0)
DPD_vals
# Out:
#                           Py2T + TGFb  A549 + TGFb  A549 + EGF  A549 + TNF  \
# No ligands and inhibtors     0.000000     0.000000    0.000000    0.000000
# TGFB, no inhibitors          1.000000     1.000000         NaN         NaN
# EGF, no inhibitors                NaN          NaN    0.048969         NaN
# TNF, no inhibitors                NaN          NaN         NaN    0.108019
# TGFBR                        0.011725     0.035727    0.032057    0.002754
# RIPK1                             NaN     0.341908    0.029818    0.013273
# IKK                          0.329925     0.465084    0.132977         NaN
# VGFR/PDGFR/FGFR              0.295921     0.263385    0.029193         NaN
# EGFR                         0.159840     0.754435    0.060670    0.190352
# PDGFR                        0.693857     0.756843    0.057392    0.119430
# FGFR                         0.311043     0.794683    0.068792    0.168037
# ...

# %%
fontAxes =  {'family' : 'Arial', 'weight' : 'bold', 'size' : 16} 
plt.rc('font', **fontAxes)

plt.figure(figsize=(15,10))
sns.heatmap(DPD_vals,annot=True, fmt='.2f',xticklabels=True,yticklabels=True,cmap='jet')
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1080">
